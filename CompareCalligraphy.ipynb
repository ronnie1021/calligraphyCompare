# %% [markdown]
# ![Example](usage.gif)

# %% [markdown]
# ## I. Setups
#
# Run the following commands if not previously run:

# %%
# run following if you aren't able to import cv2:

# !pip install --upgrade pip
# !pip install opencv-python

# %%
from utils import *

# %% [markdown]
# ## II. Prepare Images

# %%
sample_fname = "./samples/心.jpeg"
sample_image = load_image(sample_fname)

# %%
copy_fname = "./excercises/心1.jpeg"
copy_image = load_image(copy_fname)

# %% [markdown]
# ## III. Visualize & Compare

# %%
def show_image(array: np.ndarray):
    # %matplotlib inline
    plt.imshow(array)
    plt.axis("off")
    plt.show()

# %%
comparison_image = get_overlay(sample_image, copy_image)
show_image(comparison_image)

# %% [markdown]
# ## Another Run

# %%
sample_fname = "./samples/洫.jpeg"
copy_fname = "./excercises/洫1.jpeg"

# %matplotlib qt
sample_image = load_image(sample_fname)
copy_image = load_image(copy_fname)

# %%
# %matplotlib inline

compared = get_overlay(sample_image, copy_image)
show_image(compared)
